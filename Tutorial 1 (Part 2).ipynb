# %% [markdown]
# # In this tutorial’s part 2, I will cover the following:
# * Dropping Rows (Based on the null values)
# * Various Parameter In Dropping functionalities
# * Handling Missing values by Mean, Median And Mode

# %% [markdown]
# # PySpark Setup

# %%
# !pip install pyspark py4j
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("tutorial-1(p-2)").getOrCreate()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 KB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 18.0 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.2-py2.py3-none-any.whl size=281824025 sha256=a943b2073b5e129b826d45e2d496e6228a62b175ebbb4f4fe028473081568c9e
#   Stored in directory: /root/.cache/pip/wheels/b1/59/a0/a1a0624b5e865fd389919c1a10f53aec9b12195d6747710baf
# Successfully built pyspark
# ...

# %%
# Reading the Datset
df=spark.read.csv("/content/drive/MyDrive/PGD_BigData/Spark/Datasets/simple1.csv", header=True, inferSchema=True)

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|null|      null| 40000|
# |     null|  34|        10| 38000|
# |     null|  36|      null|  null|
# +---------+----+----------+------+

# %% [markdown]
# # Dropping Rows

# %%
df.na.drop().show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
#any==how
df.na.drop(how="any").show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
##threshold
df.na.drop(how="any",thresh=2).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|null|      null| 40000|
# |     null|  34|        10| 38000|
# +---------+----+----------+------+

# %%
##Subset
df.na.drop(how="any",subset=['Age']).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# |     null| 34|        10| 38000|
# |     null| 36|      null|  null|
# +---------+---+----------+------+

# %% [markdown]
# # Handling Missing values by Mean, Median And Mode
#
# For handling the missing values by by mean, median and mode, we needed imputer function, so at first we needed to setup imputer function

# %%
from pyspark.ml.feature import Imputer

imputer = Imputer(
    inputCols=['age', 'Experience', 'Salary'], 
    outputCols=["{}_imputed".format(c) for c in ['age', 'Experience', 'Salary']]
    ).setStrategy("median")

# %%
imputer.fit(df).transform(df).show()
# Out:
# +---------+----+----------+------+-----------+------------------+--------------+
# |     Name| age|Experience|Salary|age_imputed|Experience_imputed|Salary_imputed|
# +---------+----+----------+------+-----------+------------------+--------------+
# |    Krish|  31|        10| 30000|         31|                10|         30000|
# |Sudhanshu|  30|         8| 25000|         30|                 8|         25000|
# |    Sunny|  29|         4| 20000|         29|                 4|         20000|
# |     Paul|  24|         3| 20000|         24|                 3|         20000|
# |   Harsha|  21|         1| 15000|         21|                 1|         15000|
# |  Shubham|  23|         2| 18000|         23|                 2|         18000|
# |   Mahesh|null|      null| 40000|         29|                 4|         40000|
# |     null|  34|        10| 38000|         34|                10|         38000|
# |     null|  36|      null|  null|         36|                 4|         20000|
# ...
